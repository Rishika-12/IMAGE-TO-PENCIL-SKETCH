# %% [markdown]
# IMPORTING NECESSARY LIBRARIES

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# IMPORTING THE IMAGE USED

# %%
img = cv2.imread("/content/nature img.png")

# %% [markdown]
# DISPLAYING THE IMAGE USED

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=613x409 at 0x7F9F130C30D0>

# %% [markdown]
# CONVERTING IMAGE TO GRAYSCALE

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# DISPLAYING GRAYSCALE IMAGE

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=613x409 at 0x7F9F1DD396D0>

# %% [markdown]
# INVERTING THE IMAGE

# %%
invert_img = cv2.bitwise_not(gray_img)

# %% [markdown]
# DISPLAYING INVERTED IMAGE

# %%
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=613x409 at 0x7F9F13063B10>

# %% [markdown]
# SMOOTHING THE IMAGE USING GAUSSIAN BLUR

# %%
smooth_img = cv2.GaussianBlur(invert_img,(21,21),sigmaX=0,sigmaY=0)

# %% [markdown]
# DISPLAYING SMOOTH IMAGE

# %%
cv2_imshow(smooth_img)
# Out:
# <PIL.Image.Image image mode=L size=613x409 at 0x7F9F13051890>

# %% [markdown]
# CONVERTING TO PENCIL SKETCH

# %%
def finalsketch(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %% [markdown]
# DISPLAYING FINAL PENCIL SKETCH

# %%
final_img = finalsketch(gray_img, smooth_img)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=613x409 at 0x7F9F11FF5AD0>

# %% [markdown]
# COMPARING PICTURE USED AND SKETCH OBTAINED

# %%
print("Image used")
cv2_imshow(img)  
print("\n")
print("Pencil sketch obtained using image")
cv2_imshow(final_img)
# Out:
# Image used
# <PIL.Image.Image image mode=RGB size=613x409 at 0x7F9F1304A9D0>
# Pencil sketch obtained using image
# <PIL.Image.Image image mode=L size=613x409 at 0x7F9F130AA890>

# %% [markdown]
# THANK YOU!
